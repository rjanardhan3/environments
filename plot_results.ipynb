# %%
import matplotlib.pyplot as plt

# %%
bc_10_trajectories = {
    "seals:seals/CartPole-v0": {
        "before_training": 8.3,
        "after_training": 500.0,
        "expert": 500.0
    },
    "seals/Ant-v1": {
        "before_training": 1000.7498310000001,
        "after_training": 1084.5274508999998,
        "expert": 2530.674563
    },
    "seals/HalfCheetah-v1": {
        "before_training": -0.10842960000000001,
        "after_training": 1301.3433785999998,
        "expert": 1647.7428928999998
    }
}

bc_25_trajectories = {
    "seals:seals/CartPole-v0": {
        "before_training": 12.1,
        "after_training": 500.0,
        "expert": 500.0
    },
    "seals/Ant-v1": {
        "before_training": 1001.0792363,
        "after_training": 1666.2608386,
        "expert": 2530.674563
    },
    "seals/HalfCheetah-v1": {
        "before_training": -0.2206874,
        "after_training": 1473.8520941,
        "expert": 1647.7428928999998
    }
}

bc_50_trajectories = {
    "seals:seals/CartPole-v0": {
        "before_training": 15.5,
        "after_training": 500.0,
        "expert": 500.0
    },
    "seals/Ant-v1": {
        "before_training": 1001.0175158999998,
        "after_training": 2516.81327,
        "expert": 2530.674563
    },
    "seals/HalfCheetah-v1": {
        "before_training": 0.0991429,
        "after_training": 1413.8997762,
        "expert": 1647.7428928999998
    }
}

bc_100_trajectories = {
    "seals:seals/CartPole-v0": {
        "before_training": 113.8,
        "after_training": 500.0,
        "expert": 500.0
    },
    "seals/Ant-v1": {
        "before_training": 1006.013346,
        "after_training": 2581.2039605,
        "expert": 2530.674563
    },
    "seals/HalfCheetah-v1": {
        "before_training": -0.02662110000000003,
        "after_training": 1573.295919,
        "expert": 1647.7428928999998
    }
}

# %%
number_of_trajectories = [10, 25, 50, 100]
envs = ["seals:seals/CartPole-v0", "seals/Ant-v1", "seals/HalfCheetah-v1"]
# plot a line for each environment with trajectories on x-axis and reward after training on the y-axis


for env in envs:
    plt.plot(number_of_trajectories, [bc_10_trajectories[env]["after_training"] / bc_10_trajectories[env]["expert"], bc_25_trajectories[env]["after_training"] / bc_25_trajectories[env]["expert"], bc_50_trajectories[env]["after_training"] / bc_50_trajectories[env]["expert"], bc_100_trajectories[env]["after_training"] / bc_100_trajectories[env]["expert"]], label=env)
    # plt.plot(number_of_trajectories, [bc_10_trajectories[env]["before_training"], bc_25_trajectories[env]["before_training"], bc_50_trajectories[env]["before_training"], bc_100_trajectories[env]["before_training"]], label=env)
    # plt.plot(number_of_trajectories, [bc_10_trajectories[env]["expert"], bc_25_trajectories[env]["expert"], bc_50_trajectories[env]["expert"], bc_100_trajectories[env]["expert"]], label=env)

plt.xlabel("Number of trajectories")
plt.ylabel("Reward")
plt.legend()
plt.show()
